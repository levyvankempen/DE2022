# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import window, col, avg, concat, lit, from_csv
from pyspark.sql.types import StructType, StructField, LongType, StringType, DoubleType, IntegerType
from time import sleep

sparkConf = SparkConf()
sparkConf.setMaster("spark://spark-master:7077")
sparkConf.setAppName("Lab8_Ex2")
sparkConf.set("spark.driver.memory", "2g")
sparkConf.set("spark.executor.cores", "1")
sparkConf.set("spark.driver.cores", "1")

# create the spark session, which is the entry point to Spark SQL engine.
spark = SparkSession.builder.config(conf=sparkConf).getOrCreate()

dataSchema = StructType(
    [StructField("uname", StringType(), True),
     StructField("tname", StringType(), True),
     StructField("score", IntegerType(), True),
     StructField("timestamp_in_ms", LongType(), True),
     StructField("readable_time", StringType(), True)
     ])


# Read the whole dataset as a batch
kafkaStream = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "kafka1:9093") \
    .option("subscribe", "game") \
    .option("startingOffsets", "latest") \
    .load()

df = kafkaStream.selectExpr("CAST(value AS STRING)")

df1 = df.select(from_csv(df.value, dataSchema.simpleString()))

df1.printSchema()

sdf = df1.select(col("from_csv(value).*"))

sdf.printSchema()

# create the event time column 
withEventTimedf = sdf.selectExpr(
    "*",
    "cast(timestamp_in_ms/1000.0 as timestamp) as event_time")

withEventTimedf.printSchema()

avgscoredf = withEventTimedf \
    .groupBy(window(col("event_time"), "10 seconds"), "uname", "tname") \
    .agg(avg("score").alias("value"))

resultdf = avgscoredf.select(concat(col("uname"), lit(" "), col("tname")).alias("key"), col("value"))

query = resultdf \
    .writeStream \
    .queryName("avg_score_window") \
    .format("memory") \
    .outputMode("complete") \
    .start()

try:
    for x in range(100):
        spark.sql("SELECT * FROM avg_score_window").show()
        sleep(10)
except KeyboardInterrupt:
    query.stop()
    # Stop the spark context
    spark.stop()
    print("Stoped the streaming query and the spark context")
# Out:
# root
#  |-- from_csv(value): struct (nullable = true)
#  |    |-- uname: string (nullable = true)
#  |    |-- tname: string (nullable = true)
#  |    |-- score: integer (nullable = true)
#  |    |-- timestamp_in_ms: long (nullable = true)
#  |    |-- readable_time: string (nullable = true)
#
# root
#  |-- uname: string (nullable = true)
#  |-- tname: string (nullable = true)
#  |-- score: integer (nullable = true)
#  |-- timestamp_in_ms: long (nullable = true)
#  |-- readable_time: string (nullable = true)
#
# root
#  |-- uname: string (nullable = true)
#  |-- tname: string (nullable = true)
#  |-- score: integer (nullable = true)
#  |-- timestamp_in_ms: long (nullable = true)
#  |-- readable_time: string (nullable = true)
#  |-- event_time: timestamp (nullable = true)
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +---+-----+
# |key|value|
# +---+-----+
# +---+-----+
#
# +--------------------+-----+
# |                 key|value|
# +--------------------+-----+
# |user16_AmaranthKo...| 18.0|
# +--------------------+-----+
#
# +--------------------+-----+
# |                 key|value|
# +--------------------+-----+
# |user16_AmaranthKo...| 18.0|
# +--------------------+-----+
#
# +--------------------+-----+
# |                 key|value|
# +--------------------+-----+
# |user1_ArmyGreenCa...|  2.0|
# |user6_AndroidGree...| 13.0|
# |user16_ArmyGreenC...| 10.5|
# |user11_AntiqueBra...| 19.0|
# |user2_ApricotDing...|  6.0|
# |user9_AmaranthKoa...|  5.0|
# |user6_AntiqueBras...|  5.0|
# |user10_AuburnCock...| 10.0|
# |user18_ApricotDin...|  2.0|
# |user7_BananaWalla...| 15.0|
# |user15_AmaranthKo...| 13.0|
# |user10_AmaranthMa...|  2.0|
# |user8_AzureBilby ...| 14.0|
# |user4_BananaWalla...| 17.0|
# |user9_AuburnCocka...|  5.0|
# |user18_Battleship...| 11.0|
# |user14_Battleship...| 19.0|
# |user4_AuburnDingo...|  4.0|
# |user8_ArmyGreenCa...| 16.0|
# |user9_AntiqueBras...|  5.0|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+------------------+
# |                 key|             value|
# +--------------------+------------------+
# |user3_ArmyGreenCa...|               7.0|
# |user1_ArmyGreenCa...|               2.0|
# |user6_AndroidGree...|              13.0|
# |user19_AuburnDing...|              12.0|
# |user16_ArmyGreenC...|              10.5|
# |user11_AntiqueBra...|              18.5|
# |user0_ApricotDing...|               4.0|
# |user4_AzureCassow...|              19.0|
# |user2_ApricotDing...|               6.0|
# |user0_ArmyGreenCa...|              15.0|
# |user9_AmaranthKoa...|3.3333333333333335|
# |user6_AntiqueBras...|               5.0|
# |user18_ApricotDin...|               2.0|
# |user10_AuburnCock...|              10.0|
# |user7_BananaWalla...|             12.25|
# |user15_AmaranthKo...|              13.0|
# |user10_AmaranthMa...|               2.0|
# |user12_AmberCaneT...|              13.0|
# |user8_AzureBilby ...|              14.0|
# |user4_BananaWalla...|              17.0|
# +--------------------+------------------+
# only showing top 20 rows
#
# +--------------------+------------------+
# |                 key|             value|
# +--------------------+------------------+
# |user3_ArmyGreenCa...|              10.0|
# |user6_AndroidGree...|              13.0|
# |user1_ArmyGreenCa...|               6.0|
# |user19_AuburnDing...|              12.0|
# |user5_AmaranthKoa...|               8.5|
# |user5_BananaWalla...|              14.0|
# |user16_ArmyGreenC...|              10.5|
# |user11_AntiqueBra...|              18.5|
# |user17_Battleship...|              10.0|
# |user0_ApricotDing...|               4.0|
# |user4_BattleshipG...|              11.0|
# |user4_AzureCassow...|              19.0|
# |user12_AmaranthDi...|               7.0|
# |user2_ApricotDing...|               6.0|
# |user0_ArmyGreenCa...|               9.0|
# |user9_AmaranthKoa...|3.3333333333333335|
# |user6_AntiqueBras...|              12.0|
# |user3_AmaranthDin...|              18.0|
# |user18_ApricotDin...|               2.0|
# |user1_AmaranthKoa...|              12.5|
# +--------------------+------------------+
# only showing top 20 rows
#
# +--------------------+-----------------+
# |                 key|            value|
# +--------------------+-----------------+
# |user3_ArmyGreenCa...|             10.0|
# |user6_AndroidGree...|             11.0|
# |user1_ArmyGreenCa...|              8.0|
# |user19_AuburnDing...|             12.0|
# |user5_AmaranthKoa...|             12.0|
# |user11_AntiqueBra...|             18.5|
# |user5_BananaWalla...|             14.0|
# |user16_ArmyGreenC...|             10.5|
# |user17_Battleship...|             10.0|
# |user0_ApricotDing...|              4.0|
# |user4_AzureCassow...|              9.5|
# |user4_BattleshipG...|             11.0|
# |user12_AmaranthDi...|              7.0|
# |user2_ApricotDing...|              6.0|
# |user0_ArmyGreenCa...|6.666666666666667|
# |user9_AmaranthKoa...|              7.0|
# |user6_AntiqueBras...|             12.0|
# |user3_AmaranthDin...|             18.0|
# |user18_ApricotDin...|              5.5|
# |user1_AmaranthKoa...|             12.5|
# +--------------------+-----------------+
# only showing top 20 rows
#
# +--------------------+-----------------+
# |                 key|            value|
# +--------------------+-----------------+
# |user3_ArmyGreenCa...|             10.0|
# |user6_AndroidGree...|             11.0|
# |user1_ArmyGreenCa...|6.333333333333333|
# |user19_AuburnDing...|             14.5|
# |user5_AmaranthKoa...|            13.75|
# |user11_AntiqueBra...|             11.0|
# |user5_BananaWalla...|             14.0|
# |user16_ArmyGreenC...|             10.0|
# |user17_Battleship...|             13.5|
# |user0_ApricotDing...|              4.0|
# |user4_AzureCassow...|7.666666666666667|
# |user4_BattleshipG...|             11.0|
# |user12_AmaranthDi...|              9.0|
# |user2_ApricotDing...|              6.0|
# |user0_ArmyGreenCa...|6.666666666666667|
# |user9_AmaranthKoa...|              7.0|
# |user6_AntiqueBras...|             12.0|
# |user3_AmaranthDin...|             14.0|
# |user18_ApricotDin...|              5.5|
# |user1_AmaranthKoa...|             12.5|
# +--------------------+-----------------+
# only showing top 20 rows
#
# +--------------------+-----------------+
# |                 key|            value|
# +--------------------+-----------------+
# |user3_ArmyGreenCa...|             10.0|
# |user6_AndroidGree...|7.666666666666667|
# |user1_ArmyGreenCa...|6.333333333333333|
# |user19_AuburnDing...|             14.5|
# |user2_AuburnDingo...|              5.0|
# |user5_AmaranthKoa...|            13.75|
# |user11_AntiqueBra...|             11.0|
# |user5_BananaWalla...|             14.0|
# |user16_ArmyGreenC...|             10.0|
# |user17_Battleship...|             11.0|
# |user0_ApricotDing...|             10.0|
# |user4_AzureCassow...|            10.25|
# |user4_BattleshipG...|             11.0|
# |user12_AmaranthDi...|              9.0|
# |user2_ApricotDing...|             11.0|
# |user0_ArmyGreenCa...|              8.5|
# |user9_AmaranthKoa...|            8.375|
# |user6_AntiqueBras...|             12.0|
# |user3_AmaranthDin...|9.333333333333334|
# |user18_ApricotDin...|              5.5|
# +--------------------+-----------------+
# only showing top 20 rows
#
# +--------------------+------------------+
# |                 key|             value|
# +--------------------+------------------+
# |user3_ArmyGreenCa...|              10.0|
# |user5_AuburnCocka...| 5.333333333333333|
# |user6_AndroidGree...|               8.5|
# |user1_ArmyGreenCa...| 6.333333333333333|
# |user19_AuburnDing...|              14.5|
# |user2_AuburnDingo...|               4.5|
# |user5_AmaranthKoa...|10.833333333333334|
# |user11_AntiqueBra...|              10.6|
# |user5_BananaWalla...|              14.0|
# |user16_ArmyGreenC...|              7.75|
# |user17_Battleship...|              11.0|
# |user0_ApricotDing...|12.666666666666666|
# |user4_AzureCassow...|             10.25|
# |user4_BattleshipG...|              11.0|
# |user12_AmaranthDi...| 7.666666666666667|
# |user2_ApricotDing...|              11.0|
# |user0_ArmyGreenCa...|               8.5|
# |user9_AmaranthKoa...|             8.375|
# |user6_AntiqueBras...|               6.5|
# |user3_AmaranthDin...| 9.333333333333334|
# +--------------------+------------------+
# only showing top 20 rows
#
# +--------------------+------------------+
# |                 key|             value|
# +--------------------+------------------+
# |user3_ArmyGreenCa...|              9.75|
# |user5_AuburnCocka...| 5.333333333333333|
# |user6_AndroidGree...|               9.2|
# |user1_ArmyGreenCa...| 7.857142857142857|
# |user19_AuburnDing...|              14.5|
# |user2_AuburnDingo...|               4.5|
# |user5_AmaranthKoa...|             9.875|
# |user11_AntiqueBra...|              10.6|
# |user5_BananaWalla...|11.333333333333334|
# |user16_ArmyGreenC...|               7.2|
# |user17_Battleship...|              11.0|
# |user0_ApricotDing...|              9.75|
# |user4_AzureCassow...|               8.8|
# |user4_BattleshipG...|              14.5|
# |user12_AmaranthDi...| 7.666666666666667|
# |user2_AmaranthDin...|               8.0|
# |user2_ApricotDing...|              11.0|
# |user0_ArmyGreenCa...|               8.5|
# |user9_AmaranthKoa...| 9.083333333333334|
# |user6_AntiqueBras...|               6.5|
# +--------------------+------------------+
# only showing top 20 rows
#
# +--------------------+------------------+
# |                 key|             value|
# +--------------------+------------------+
# |user3_ArmyGreenCa...|              10.2|
# |user5_AuburnCocka...| 5.333333333333333|
# |user6_AndroidGree...| 9.833333333333334|
# |user1_ArmyGreenCa...|               8.5|
# |user19_AuburnDing...|              14.5|
# |user2_AuburnDingo...|               4.5|
# |user5_AmaranthKoa...|               8.9|
# |user11_AntiqueBra...|              10.6|
# |user5_BananaWalla...|              8.75|
# |user16_ArmyGreenC...|               7.2|
# |user17_Battleship...|              13.0|
# |user0_ApricotDing...| 9.833333333333334|
# |user4_AzureCassow...|               8.8|
# |user4_BattleshipG...|14.333333333333334|
# |user12_AmaranthDi...| 7.666666666666667|
# |user2_AmaranthDin...|               8.0|
# |user2_ApricotDing...|              11.0|
# |user0_ArmyGreenCa...|               8.5|
# |user9_AmaranthKoa...|10.214285714285714|
# |user6_AntiqueBras...|               7.8|
# +--------------------+------------------+
# only showing top 20 rows
#
# +--------------------+------------------+
# |                 key|             value|
# +--------------------+------------------+
# |user3_ArmyGreenCa...| 9.833333333333334|
# |user5_AuburnCocka...|              6.75|
# |user6_AndroidGree...| 8.714285714285714|
# |user1_ArmyGreenCa...|               8.5|
# |user19_AuburnDing...|              14.0|
# |user2_AuburnDingo...|               4.5|
# |user5_AmaranthKoa...| 9.272727272727273|
# |user11_AntiqueBra...|              10.0|
# |user5_BananaWalla...|              8.75|
# |user16_ArmyGreenC...| 7.166666666666667|
# |user17_Battleship...|              13.0|
# |user0_ApricotDing...| 9.833333333333334|
# |user4_AzureCassow...|               8.8|
# |user4_BattleshipG...|14.333333333333334|
# |user12_AmaranthDi...|              7.75|
# |user2_AmaranthDin...|              11.5|
# |user2_ApricotDing...|              11.0|
# |user0_ArmyGreenCa...|               7.8|
# |user9_AmaranthKoa...|              10.8|
# |user6_AntiqueBras...|               7.8|
# +--------------------+------------------+
# only showing top 20 rows
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
# RuntimeError: reentrant call inside <_io.BufferedReader name=50>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/conda/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/local/spark/python/pyspark/context.py", line 362, in signal_handler
#     self.cancelAllJobs()
#   File "/usr/local/spark/python/pyspark/context.py", line 1447, in cancelAllJobs
#     self._jsc.sc().cancelAllJobs()
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1321, in __call__
#     return_value = get_return_value(
#   File "/usr/local/spark/python/pyspark/sql/utils.py", line 190, in deco
#     return f(*a, **kw)
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/protocol.py", line 334, in get_return_value
#     raise Py4JError(
# py4j.protocol.Py4JError: An error occurred while calling o24.sc
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# Cell In [1], line 67
#      65 try:
#      66     for x in range(100):
# ---> 67         spark.sql("SELECT * FROM avg_score_window").show()
#      68         sleep(10)
#      69 except KeyboardInterrupt:
#
# File /usr/local/spark/python/pyspark/sql/dataframe.py:606, in DataFrame.show(self, n, truncate, vertical)
#     603     raise TypeError("Parameter 'vertical' must be a bool")
#     605 if isinstance(truncate, bool) and truncate:
# --> 606     print(self._jdf.showString(n, 20, vertical))
#     607 else:
#     608     try:
#
# File /usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /usr/local/spark/python/pyspark/sql/utils.py:190, in capture_sql_exception.<locals>.deco(*a, **kw)
#     188 def deco(*a: Any, **kw: Any) -> Any:
#     189     try:
# --> 190         return f(*a, **kw)
#     191     except Py4JJavaError as e:
#     192         converted = convert_exception(e.java_exception)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/protocol.py:334, in get_return_value(answer, gateway_client, target_id, name)
#     330             raise Py4JError(
#     331                 "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332                 format(target_id, ".", name, value))
#     333     else:
# --> 334         raise Py4JError(
#     335             "An error occurred while calling {0}{1}{2}".
#     336             format(target_id, ".", name))
#     337 else:
#     338     type = answer[1]
#
# Py4JError: An error occurred while calling o172.showString

# %%
# Stop the spark context
spark.stop()
